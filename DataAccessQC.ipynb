# %% [markdown]
# ![logo-gt.png](attachment:logo-gt.png)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h1>BIOS 4150/BIOL 6150</h1>
#     <h3>Instructor: Dr. King Jordan</h3>
#     <p>TAs: Shivam Sharma (shivamsharma13@gatech.edu) & Vishva Natarajan (vishvanata@gatech.edu)</p>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h2>Project 1 (Data access & QC) starter notebook</h2>
#     <h3>Deadline: 12:00AM, October 20th, 2023</h3>
# </div>

# %% [markdown]
# ---

# %% [markdown]
# # **1. Your assigned 1000 Genomes individual**
# ### *Total Questions: 3*
# ### *Total Points: 10+10+20 = 40*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>1.1 Does you group have an assigned individual ID from the 1000 Genomes Project?</h3>
#     <p>Find the individual on the international genomes website and paste a screenshot below</p>
# </div>

# %%
##Add image here for 1.1

# %% [markdown]
# ![Q1%20%281%29.PNG](attachment:Q1%20%281%29.PNG)

# %% [markdown]
# <p style="color:red"> image stored in [/storage/ice-shared/biol6150/ProjectSubmissions/Group19/Project1/Q1.PNG]</p>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>1.2 What population does you assigned individual belong to?</h3>
#     <p>Write about where the geographical location of where this individual lived at the time of recruitment? </p>
# </div>

# %%
#Write about the individual and their ancestors here.

# %% [markdown]
# <span style="color:red">The individual lived in Medellin, Colombia.</span>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>1.3 More about your individual's population?</h3>
#     <p>Read more about this population and write about their recent historical  (100-500 years) ancestors.</p>
# </div>

# %%
#Write about the individual and their ancestors here.

# %% [markdown]
# <span style="color:red">The individual is a Colombian with American ancestry. All four of their ancestors were born in Colombia.</span>

# %% [markdown]
# # **2. Exome sequencing**
# ### *Total Questions: 3*
# ### *Total Points: 20+20= 40*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>2.1 Does your assigned individual has exome sequencing data? If yes, then what is the SRR ID for that sequencing run?</h3>
#     <p>Does you individual have multiple SRR IDs? In case they do, which one would you pick? (Hint: The sequencing information is coming from the same individual; but larger file size might be more preferable)</p>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <h3>Multiple fastq files for your 1KGP individual</h3>
#     <p>On the FTP server, it is expected that you will have more than 1 pair of fastq files. What you need to decide on is which set of fastq files make the most sense. A few good checks are the size of the file (maybe 1-12GB), presence of an SRR ID, elimination of exceptionally small files etc. </p>
#     <p>If your team is still confused, please reach out to us regarding this.</p>
# </div>

# %%
#Write the SRR ID here along with your reasoning for selection.

# %% [markdown]
# <h4 style="color:red">SRR766014</h4>
# <p style="color:red">There was only 1 pair of exome sequencing data.</p>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>2.2 Looking at just the exome sequencing of this individual, how many variants would you expect them to carry compared to the reference genome?</h3>
#     <p>Keep in mind this is 1 individual, and learn about the expected number of variants from WGS, WES, and Genotyping</p>
# </div>

# %%
#Write about the variant information here.

# %% [markdown]
# <span style="color:red">Because we are looking at exome sequencing, we can expect 10,000-20,000 variants compared to the reference genome. However, if we were looking at WGS, we would expect millions of variants.</span>

# %% [markdown]
# # **3. Data access**
# ### *Total Questions: 3*
# ### *Total Points: 20+20 = 40*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>3.1 Download the exome sequencing data for this individual and write the size of the files?</h3>
#     <p>3.1.1 How many files do you have? Is the sequencing paired?</p>
#     <p>3.1.2 How many reads are present in each file? </p>
# </div>

# %%
#Show you download commamd.
# !wget ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG01124/sequence_read/SRR766014_1.filt.fastq.gz
# !wget ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG01124/sequence_read/SRR766014_2.filt.fastq.gz
# Out:
# --2023-10-18 21:02:53--  ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG01124/sequence_read/SRR766014_1.filt.fastq.gz
#            => ‘SRR766014_1.filt.fastq.gz.1’
# Resolving ftp.1000genomes.ebi.ac.uk (ftp.1000genomes.ebi.ac.uk)... 193.62.193.167
# Connecting to ftp.1000genomes.ebi.ac.uk (ftp.1000genomes.ebi.ac.uk)|193.62.193.167|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/ftp/phase3/data/HG01124/sequence_read ... done.
# ==> SIZE SRR766014_1.filt.fastq.gz ... 2813375039
# ==> PASV ... done.    ==> RETR SRR766014_1.filt.fastq.gz ... done.
# Length: 2813375039 (2.6G) (unauthoritative)
#
# SRR766014_1.filt.fa 100%[===================>]   2.62G  62.9MB/s    in 1m 46s
#
# 2023-10-18 21:04:41 (25.3 MB/s) - ‘SRR766014_1.filt.fastq.gz.1’ saved [2813375039]
#
# --2023-10-18 21:04:41--  ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG01124/sequence_read/SRR766014_2.filt.fastq.gz
# ...

# %%
#Move the files to an appropriate place and 'ls' that directory. We want to see the file names and the file sizes
# !mkdir Project1_ExomeData
# !mv SRR766014_1.filt.fastq.gz Project1_ExomeData
# !mv SRR766014_2.filt.fastq.gz Project1_ExomeData

# %%
#Write about the fastq file here.

# !zcat ~/biol6150/ProjectSubmissions/Group19/Project1/Project1_ExomeData/SRR766014_1.filt.fastq.gz | head 
# !echo "----"
# !zcat ~/biol6150/ProjectSubmissions/Group19/Project1/Project1_ExomeData/SRR766014_2.filt.fastq.gz | head

# %% [markdown]
# <p style="color:red">We have two files and the sequencing is paired.</p>

# %%
#Write about the fastq file here.
! zcat ~/biol6150/ProjectSubmissions/Group19/Project1/Project1_ExomeData/SRR766014_1.filt.fastq.gz | wc -l
# Out:
# 134144032

# %%
#Write about the fastq file here.
! zcat ~/biol6150/ProjectSubmissions/Group19/Project1/Project1_ExomeData/SRR766014_2.filt.fastq.gz | wc -l
# Out:
# 134144032

# %% [markdown]
# <p style="color:red">33536008 reads are present in each file.</p>

# %% [markdown]
# # **4. Pre-QC with FastQC**
# ### *Total Questions: 2*
# ### *Total Points: 20+20+20 = 60*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>4.1 Show your exact command below.</h3>
# </div>

# %%
#Command here.
# !mkdir -p ~/biol6150/ProjectSubmissions/Group19/Project1/fastQCBeforeTrimming
# !mkdir -p ~/biol6150/ProjectSubmissions/Group19/Project1/Trimming
# !mkdir -p ~/biol6150/ProjectSubmissions/Group19/Project1/fastQCAfterTrimming

# %%
# !fastqc -o ~/biol6150/ProjectSubmissions/Group19/Project1/fastQCBeforeTrimming ~/biol6150/ProjectSubmissions/Group19/Project1/Project1_ExomeData/SRR766014_1.filt.fastq.gz ~/biol6150/ProjectSubmissions/Group19/Project1/Project1_ExomeData/SRR766014_2.filt.fastq.gz

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>4.2 Show <i>per base sequencing quality</i>?</h3>
#     <p>Add a screenshot below</p>
# </div>

# %%
##Add image here for 4.1

# %% [markdown]
# <p style="color:red">For SRR766014_1.filt.fastq.gz</p>

# %% [markdown]
# ![Screenshot%202023-10-17%20at%203.11.41%20PM.png](attachment:Screenshot%202023-10-17%20at%203.11.41%20PM.png)

# %% [markdown]
# <p style="color:red">For SRR766014_2.filt.fastq.gz</p>

# %% [markdown]
# ![Screenshot%202023-10-17%20at%203.12.29%20PM.png](attachment:Screenshot%202023-10-17%20at%203.12.29%20PM.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>4.3 Show <i>Per base sequence content</i>?</h3>
#     <p>Add a screenshot below</p>
# </div>

# %%
##Add image here for 4.2

# %% [markdown]
# <p style="color:red">For SRR766014_1.filt.fastq.gz</p>

# %% [markdown]
# ![Screenshot%202023-10-17%20at%203.13.04%20PM.png](attachment:Screenshot%202023-10-17%20at%203.13.04%20PM.png)

# %% [markdown]
# <p style="color:red">For SRR766014_2.filt.fastq.gz</p>

# %% [markdown]
# ![Screenshot%202023-10-17%20at%203.14.02%20PM.png](attachment:Screenshot%202023-10-17%20at%203.14.02%20PM.png)

# %% [markdown]
# # **5. Trimming with fastp or trimmmomatic**
# ### *Total Questions: 3*
# ### *Total Points: 20+20+20 = 60*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>5.1 What was the tools and command you used?</h3>
#     <p>Write the tool name and exact command below</p>
# </div>

# %% [markdown]
# <p style="color:red">Tool:   fastp</p>

# %%
#Tool: fastp

# !fastp -i ~/biol6150/ProjectSubmissions/Group19/Project1/Project1_ExomeData/SRR766014_1.filt.fastq.gz -I ~/biol6150/ProjectSubmissions/Group19/Project1/Project1_ExomeData/SRR766014_2.filt.fastq.gz -o ~/biol6150/ProjectSubmissions/Group19/Project1/Trimming/SRR766014_1.Trimmed.fastq.gz -O ~/biol6150/ProjectSubmissions/Group19/Project1/Trimming/SRR766014_2.Trimmed.fastq.gz -f 12 -t 15

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>5.2 How did you perform the trimming?</h3>
#     <p>Did you use dynamic built in features or hard coded parameters?</p>
#     <p>Did you have to go back and repeat the trimming after run(s) for <b>postQC?</b></p>
# </div>

# %% [markdown]
# <p style="color:red">I used -f 12 to trim 12 bases from the front and -t 15 to trim 15 bases from the back.They are hard coded parameters.<br>
# I did not need to go back and repeat the trimming for postQC because quality remained above 20.</p>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>5.3 What percentage of reads did you lose in the trimming process?</h3>
#     <p>5.3.1 Write the total number of reads before and after trimming</p>
#     <p>5.3.2 If you had a paired fastq file, are there any reads after trimming present in one file and not the other? (eg: present in reverse but not in forward?)</p>
#
# </div>

# %% [markdown]
# <p style="color:red">Before trimming: Read1: 33536008 Read2: 33536008<br>
#     After trimming: Read1: 32451619 Read2: 32451619<br>
#     We lost 3.23% of reads<br>
# Both files have the same reads after trimming</p>

# %%
# !zcat ~/biol6150/ProjectSubmissions/Group19/Project1/Trimming/SRR766014_1.Trimmed.fastq.gz |grep -Eo "^@SRR.*\/" > ~/biol6150/ProjectSubmissions/Group19/Project1/Trimming/headers_1.txt
# !zcat ~/biol6150/ProjectSubmissions/Group19/Project1/Trimming/SRR766014_2.Trimmed.fastq.gz |grep -Eo "^@SRR.*\/" > ~/biol6150/ProjectSubmissions/Group19/Project1/Trimming/headers_2.txt

# !comm -3 <(sort ~/biol6150/ProjectSubmissions/Group19/Project1/Trimming/headers_1.txt) <(sort ~/biol6150/ProjectSubmissions/Group19/Project1/Trimming/headers_2.txt)

# %% [markdown]
# <p style="color:red">There are no reads that are extra in forward or reverse</p>

# %% [markdown]
# # **6. Post-QC with FastQC?**
# ### *Total Questions: 2*
# ### *Total Points: 20+20+20 = 60*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>6.1 Show your exact command below.</h3>
# </div>

# %%
# !fastqc -o ~/biol6150/ProjectSubmissions/Group19/Project1/fastQCAfterTrimming/ ~/biol6150/ProjectSubmissions/Group19/Project1/Trimming/SRR766014_1.Trimmed.fastq.gz ~/biol6150/ProjectSubmissions/Group19/Project1/Trimming/SRR766014_2.Trimmed.fastq.gz

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>6.2 Show <i>per base sequencing quality</h3>
#     <p>If the quality was falling below 20 for certain regions then trim it. Add a screenshot below</p>
# </div>

# %% [markdown]
# <p style="color:red">For SRR766014_1.filt.fastq.gz</p>

# %% [markdown]
# ![Forward%20read%20after%20qc%20oer%20base%20sq.png](attachment:Forward%20read%20after%20qc%20oer%20base%20sq.png)

# %% [markdown]
# <p style="color:red">For SRR766014_2.filt.fastq.gz</p>

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>6.3 Show <i>Per base sequence content</i>?</h3>
#     <p>Ideally we shouldn't see adapters at the beginning of the reads in the fastq files. Add a screenshot below</p>
# </div>

# %% [markdown]
# <p style="color:red">For SRR766014_1.filt.fastq.gz</p>

# %% [markdown]
# ![Forward%20read%20after%20qc%20per%20base%20sc.png](attachment:Forward%20read%20after%20qc%20per%20base%20sc.png)

# %% [markdown]
# <p style="color:red">For SRR766014_2.filt.fastq.gz</p>

# %% [markdown]
# ![1.2.png](attachment:1.2.png)

# %%
# !pwd
# Out:
# /storage/ice-shared/biol6150/ProjectSubmissions/Group19/Project1

# %%
# %%bash
# prefetch SRR23132805
# Out:
# 2023-12-02T00:12:18 prefetch.3.0.8: Current preference is set to retrieve SRA Normalized Format files with full base quality scores.
# 2023-12-02T00:12:19 prefetch.3.0.8: 1) Downloading 'SRR23132805'...
# 2023-12-02T00:12:19 prefetch.3.0.8: SRA Normalized Format file is being retrieved, if this is different from your preference, it may be due to current file availability.
# 2023-12-02T00:12:19 prefetch.3.0.8:  Downloading via HTTPS...
# 2023-12-02T00:13:27 prefetch.3.0.8:  HTTPS download succeed
# 2023-12-02T00:13:31 prefetch.3.0.8:  'SRR23132805' is valid
# 2023-12-02T00:13:31 prefetch.3.0.8: 1) 'SRR23132805' was downloaded successfully
# 2023-12-02T00:13:31 prefetch.3.0.8: 'SRR23132805' has 0 unresolved dependencies

# %%
# !fasterq-dump SRR23132805
# Out:
# spots read      : 28,229,032
# reads read      : 56,458,064
# reads written   : 56,458,064

# %%
# !fastqc -o ~/biol6150/ProjectSubmissions/Group19/Project1/ ~/biol6150/ProjectSubmissions/Group19/Project1/SRR23132805_1.fastq ~/biol6150/ProjectSubmissions/Group19/Project1/SRR23132805_2.fastq
# Out:
# Skipping '/home/hice1/ssudhakar36/biol6150/ProjectSubmissions/Group19/Project1/SRR23132805_1.fastq' which didn't exist, or couldn't be read
# Skipping '/home/hice1/ssudhakar36/biol6150/ProjectSubmissions/Group19/Project1/SRR23132805_2.fastq' which didn't exist, or couldn't be read
